# %%
import pandas as pd

# %%
df = pd.read_excel('/content/MDCOVID19_CasesByRaceAndEthnicityDistribution.xlsx')

# %%
df
# Out:
#     MDCOVID19_CasesByRaceAndEthnicityDistribution (2)  ...     Unnamed: 7
# 0                                            OBJECTID  ...  Not_Available
# 1                                                   1  ...            922
# 2                                                   2  ...            NaN
# 3                                                   3  ...           1354
# 4                                                   4  ...           1507
# ..                                                ...  ...            ...
# 321                                               321  ...          52079
# 322                                               322  ...          52100
# 323                                               323  ...          52141
# 324                                               324  ...          52172
# 325                                               325  ...          52212
#
# [326 rows x 8 columns]

# %%
df = pd.read_excel('/content/MDCOVID19_CasesByRaceAndEthnicityDistribution.xlsx', skiprows=[0])

# %%
df
# Out:
#      OBJECTID         DATE  African_American  ...   Asian    Other  Not_Available
# 0           1  2020/04/06             1521.0  ...    74.0    321.0          922.0
# 1           2   2020/04/07               NaN  ...     NaN      NaN            NaN
# 2           3   2020/04/08            2064.0  ...   122.0    449.0         1354.0
# 3           4   2020/04/09            2304.0  ...   136.0    544.0         1507.0
# 4           5   2020/04/10            2599.0  ...   153.0    643.0         1690.0
# ..        ...          ...               ...  ...     ...      ...            ...
# 320       321   2021/02/20          107295.0  ...  8427.0  17651.0        52079.0
# 321       322   2021/02/21          107496.0  ...  8444.0  17674.0        52100.0
# 322       323   2021/02/22          107690.0  ...  8461.0  17710.0        52141.0
# 323       324   2021/02/23          107945.0  ...  8479.0  17743.0        52172.0
# ...

# %%
df.head()
# Out:
#    OBJECTID         DATE  African_American  ...  Asian  Other  Not_Available
# 0         1  2020/04/06             1521.0  ...   74.0  321.0          922.0
# 1         2   2020/04/07               NaN  ...    NaN    NaN            NaN
# 2         3   2020/04/08            2064.0  ...  122.0  449.0         1354.0
# 3         4   2020/04/09            2304.0  ...  136.0  544.0         1507.0
# 4         5   2020/04/10            2599.0  ...  153.0  643.0         1690.0
#
# [5 rows x 8 columns]

# %%
df.dtypes
# Out:
# OBJECTID              int64
# DATE                 object
# African_American    float64
# White               float64
# Hispanic            float64
# Asian               float64
# Other               float64
# Not_Available       float64
# dtype: object

# %%
df.drop(['OBJECTID'], axis=1)
# Out:
#             DATE  African_American     White  ...   Asian    Other  Not_Available
# 0    2020/04/06             1521.0    1207.0  ...    74.0    321.0          922.0
# 1     2020/04/07               NaN       NaN  ...     NaN      NaN            NaN
# 2     2020/04/08            2064.0    1540.0  ...   122.0    449.0         1354.0
# 3     2020/04/09            2304.0    1694.0  ...   136.0    544.0         1507.0
# 4     2020/04/10            2599.0    1883.0  ...   153.0    643.0         1690.0
# ..           ...               ...       ...  ...     ...      ...            ...
# 320   2021/02/20          107295.0  129550.0  ...  8427.0  17651.0        52079.0
# 321   2021/02/21          107496.0  129883.0  ...  8444.0  17674.0        52100.0
# 322   2021/02/22          107690.0  130102.0  ...  8461.0  17710.0        52141.0
# 323   2021/02/23          107945.0  130344.0  ...  8479.0  17743.0        52172.0
# ...

# %%
Total_Cases = []
for index, row in df.iterrows():
     Total_Cases.append(row.African_American + row.White + row.Hispanic + row.Asian + row.Other + row.Not_Available)

# %%
Total_Cases
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  8936.0,
#  nan,
#  10032.0,
#  10784.0,
#  11572.0,
#  12308.0,
#  12830.0,
#  13684.0,
#  14193.0,
#  14775.0,
#  15737.0,
#  16616.0,
#  17766.0,
#  18581.0,
#  19487.0,
#  20113.0,
#  20849.0,
#  21742.0,
#  23472.0,
#  24473.0,
#  25462.0,
#  26408.0,
#  27117.0,
#  28163.0,
#  29374.0,
#  30485.0,
#  31534.0,
#  32587.0,
#  33373.0,
#  34061.0,
#  34812.0,
#  35903.0,
#  36986.0,
#  37968.0,
#  38804.0,
#  39762.0,
#  41546.0,
#  42323.0,
#  43531.0,
#  44424.0,
#  45495.0,
#  46313.0,
#  47152.0,
#  47687.0,
#  48423.0,
#  49709.0,
#  50988.0,
#  52015.0,
#  52778.0,
#  53327.0,
#  54175.0,
#  54982.0,
#  55858.0,
#  56770.0,
#  57482.0,
#  57973.0,
#  58404.0,
#  58904.0,
#  59465.0,
#  60197.0,
#  60613.0,
#  61305.0,
#  61701.0,
#  62032.0,
#  62409.0,
#  62969.0,
#  63229.0,
#  63548.0,
#  63956.0,
#  64306.0,
#  64603.0,
#  65007.0,
#  65337.0,
#  65777.0,
#  66115.0,
#  66450.0,
#  66777.0,
#  67254.0,
#  67559.0,
# ...

# %%
df['Total_Cases'] = Total_Cases

# %%
df.head()
# Out:
#    OBJECTID         DATE  African_American  ...  Other  Not_Available  Total_Cases
# 0         1  2020/04/06             1521.0  ...  321.0          922.0          NaN
# 1         2   2020/04/07               NaN  ...    NaN            NaN          NaN
# 2         3   2020/04/08            2064.0  ...  449.0         1354.0          NaN
# 3         4   2020/04/09            2304.0  ...  544.0         1507.0          NaN
# 4         5   2020/04/10            2599.0  ...  643.0         1690.0          NaN
#
# [5 rows x 9 columns]

# %%
df.dropna(how='all')
# Out:
#      OBJECTID         DATE  ...  Not_Available  Total_Cases
# 0           1  2020/04/06   ...          922.0          NaN
# 1           2   2020/04/07  ...            NaN          NaN
# 2           3   2020/04/08  ...         1354.0          NaN
# 3           4   2020/04/09  ...         1507.0          NaN
# 4           5   2020/04/10  ...         1690.0          NaN
# ..        ...          ...  ...            ...          ...
# 320       321   2021/02/20  ...        52079.0     375737.0
# 321       322   2021/02/21  ...        52100.0     376248.0
# 322       323   2021/02/22  ...        52141.0     376755.0
# 323       324   2021/02/23  ...        52172.0     377334.0
# 324       325   2021/02/24  ...        52212.0     355788.0
#
# [325 rows x 9 columns]

# %%
df1=df.dropna()

# %%
df1
# Out:
#      OBJECTID        DATE  ...  Not_Available  Total_Cases
# 7           8  2020/04/13  ...         1705.0       8936.0
# 9          10  2020/04/15  ...         2221.0      10032.0
# 10         11  2020/04/16  ...         2476.0      10784.0
# 11         12  2020/04/17  ...         2552.0      11572.0
# 12         13  2020/04/18  ...         2669.0      12308.0
# ..        ...         ...  ...            ...          ...
# 320       321  2021/02/20  ...        52079.0     375737.0
# 321       322  2021/02/21  ...        52100.0     376248.0
# 322       323  2021/02/22  ...        52141.0     376755.0
# 323       324  2021/02/23  ...        52172.0     377334.0
# 324       325  2021/02/24  ...        52212.0     355788.0
#
# [317 rows x 9 columns]

# %%
df1.count()
# Out:
# OBJECTID            317
# DATE                317
# African_American    317
# White               317
# Hispanic            317
# Asian               317
# Other               317
# Not_Available       317
# Total_Cases         317
# dtype: int64

# %%
df1.head()
# Out:
#     OBJECTID        DATE  African_American  ...  Other  Not_Available  Total_Cases
# 7          8  2020/04/13            3512.0  ...  961.0         1705.0       8936.0
# 9         10  2020/04/15            3724.0  ...  357.0         2221.0      10032.0
# 10        11  2020/04/16            3978.0  ...  376.0         2476.0      10784.0
# 11        12  2020/04/17            4301.0  ...  429.0         2552.0      11572.0
# 12        13  2020/04/18            4557.0  ...  458.0         2669.0      12308.0
#
# [5 rows x 9 columns]

# %%
df1.dtypes
# Out:
# OBJECTID              int64
# DATE                 object
# African_American    float64
# White               float64
# Hispanic            float64
# Asian               float64
# Other               float64
# Not_Available       float64
# Total_Cases         float64
# dtype: object

# %%
df1['DATE'] = pd.to_datetime(df1['DATE'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1=df1.set_index('DATE')

# %%
df1.index
# Out:
# DatetimeIndex(['2020-04-13', '2020-04-15', '2020-04-16', '2020-04-17',
#                '2020-04-18', '2020-04-19', '2020-04-20', '2020-04-21',
#                '2020-04-22', '2020-04-23',
#                ...
#                '2021-02-15', '2021-02-16', '2021-02-17', '2021-02-18',
#                '2021-02-19', '2021-02-20', '2021-02-21', '2021-02-22',
#                '2021-02-23', '2021-02-24'],
#               dtype='datetime64[ns]', name='DATE', length=317, freq=None)

# %%
df1
# Out:
#             OBJECTID  African_American  ...  Not_Available  Total_Cases
# DATE                                    ...
# 2020-04-13         8            3512.0  ...         1705.0       8936.0
# 2020-04-15        10            3724.0  ...         2221.0      10032.0
# 2020-04-16        11            3978.0  ...         2476.0      10784.0
# 2020-04-17        12            4301.0  ...         2552.0      11572.0
# 2020-04-18        13            4557.0  ...         2669.0      12308.0
# ...              ...               ...  ...            ...          ...
# 2021-02-20       321          107295.0  ...        52079.0     375737.0
# 2021-02-21       322          107496.0  ...        52100.0     376248.0
# 2021-02-22       323          107690.0  ...        52141.0     376755.0
# 2021-02-23       324          107945.0  ...        52172.0     377334.0
# 2021-02-24       325          108295.0  ...        52212.0     355788.0
#
# [317 rows x 8 columns]

# %%
df1 = df1.drop(['OBJECTID'], axis=1)

# %%
df1.loc['2020-12-14	']
# Out:
# African_American     69786.0
# White                74295.0
# Hispanic             42968.0
# Asian                 4790.0
# Other                10853.0
# Not_Available        34269.0
# Total_Cases         236961.0
# Name: 2020-12-14 00:00:00, dtype: float64

# %%
ax=df1[['Total_Cases']].plot(figsize=(24,10), lw=6, title='Change in Complete Real Gross Domestic Product Over Time');
ax.set_xlabel("Date")
ax.set_ylabel("Cases in Maryland")

#ax=df1[['Gross Domestic Product','Consumption']].plot(figsize=(24,10),title='Change in Complete Real Gross Domestic Product Over Time');
#ax.set_xlabel("Date")
#ax.set_ylabel("Consumption & GDP")
# Out:
# Text(0, 0.5, 'Cases in Maryland')

# %%
ax=df1[['Total_Cases', 'African_American', 'White', 'Hispanic', 'Asian']].plot(figsize=(24,10), lw=6, title='Change in Complete Real Gross Domestic Product Over Time');
ax.set_xlabel("Date")
ax.set_ylabel("Cases in Maryland")
# Out:
# Text(0, 0.5, 'Cases in Maryland')

# %%
print(df1['Total_Cases'].median())
print(df1['Total_Cases'].mean())
print(df1['Total_Cases'].std())
print(df1['Total_Cases'].var())
print(df1['Total_Cases'].max())
print(df1['Total_Cases'].min())
# Out:
# 119744.0
# 150528.77602523658
# 106181.10537460555
# 11274427138.57309
# 377334.0
# 8936.0

# %%
import seaborn as sns

# %%
sns.pairplot(df1)

# %%
df1.head()
# Out:
#             African_American   White  ...  Not_Available  Total_Cases
# DATE                                  ...
# 2020-04-13            3512.0  2547.0  ...         1705.0       8936.0
# 2020-04-15            3724.0  2425.0  ...         2221.0      10032.0
# 2020-04-16            3978.0  2535.0  ...         2476.0      10784.0
# 2020-04-17            4301.0  2681.0  ...         2552.0      11572.0
# 2020-04-18            4557.0  2869.0  ...         2669.0      12308.0
#
# [5 rows x 7 columns]

# %%
df2=df1

# %%
df2.head()
# Out:
#             African_American   White  ...  Not_Available  Total_Cases
# DATE                                  ...
# 2020-04-13            3512.0  2547.0  ...         1705.0       8936.0
# 2020-04-15            3724.0  2425.0  ...         2221.0      10032.0
# 2020-04-16            3978.0  2535.0  ...         2476.0      10784.0
# 2020-04-17            4301.0  2681.0  ...         2552.0      11572.0
# 2020-04-18            4557.0  2869.0  ...         2669.0      12308.0
#
# [5 rows x 7 columns]

# %%
#df1 = df1.drop(['OBJECTID'], axis=1)

# %%
AfAm_Dist = []
for index, row in df2.iterrows():
     AfAm_Dist.append((row.African_American / row.	Total_Cases * 100))

# %%
#df2 = df2.drop(['Percent'], axis=1)

# %%
df2['AfAm_Dist'] = AfAm_Dist

# %%
df2.head()
# Out:
#             African_American   White  ...  Total_Cases  AfAm_Dist
# DATE                                  ...
# 2020-04-13            3512.0  2547.0  ...       8936.0  39.301701
# 2020-04-15            3724.0  2425.0  ...      10032.0  37.121212
# 2020-04-16            3978.0  2535.0  ...      10784.0  36.887982
# 2020-04-17            4301.0  2681.0  ...      11572.0  37.167300
# 2020-04-18            4557.0  2869.0  ...      12308.0  37.024699
#
# [5 rows x 8 columns]

# %%
White_Dist = []
for index, row in df2.iterrows():
     White_Dist.append((row.White / row.Total_Cases * 100))

Hispanic_Dist = []
for index, row in df2.iterrows():
     Hispanic_Dist.append((row.Hispanic / row.Total_Cases * 100))

Asian_Dist = []
for index, row in df2.iterrows():
     Asian_Dist.append((row.Asian / row.Total_Cases * 100))    

Other_Dist = []
for index, row in df2.iterrows():
     Other_Dist.append((row.Other / row.Total_Cases * 100))

Not_Available_Dist = []
for index, row in df2.iterrows():
     Not_Available_Dist.append((row.Not_Available / row.Total_Cases * 100))

# %%
df2['White_Dist'] = White_Dist

df2['Hispanic_Dist'] = Hispanic_Dist

df2['Asian_Dist'] = Asian_Dist

df2['Other_Dist'] = Other_Dist

df2['Not_Available_Dist'] = Not_Available_Dist

# %%
df2.head()
# Out:
#             African_American   White  ...  Other_Dist  Not_Available_Dist
# DATE                                  ...
# 2020-04-13            3512.0  2547.0  ...   10.754252           19.080125
# 2020-04-15            3724.0  2425.0  ...    3.558612           22.139155
# 2020-04-16            3978.0  2535.0  ...    3.486647           22.959941
# 2020-04-17            4301.0  2681.0  ...    3.707224           22.053232
# 2020-04-18            4557.0  2869.0  ...    3.721157           21.685083
#
# [5 rows x 13 columns]

# %%
df2
# Out:
#             African_American     White  ...  Other_Dist  Not_Available_Dist
# DATE                                    ...
# 2020-04-13            3512.0    2547.0  ...   10.754252           19.080125
# 2020-04-15            3724.0    2425.0  ...    3.558612           22.139155
# 2020-04-16            3978.0    2535.0  ...    3.486647           22.959941
# 2020-04-17            4301.0    2681.0  ...    3.707224           22.053232
# 2020-04-18            4557.0    2869.0  ...    3.721157           21.685083
# ...                      ...       ...  ...         ...                 ...
# 2021-02-20          107295.0  129550.0  ...    4.697701           13.860493
# 2021-02-21          107496.0  129883.0  ...    4.697434           13.847250
# 2021-02-22          107690.0  130102.0  ...    4.700668           13.839498
# 2021-02-23          107945.0  130344.0  ...    4.702200           13.826477
# 2021-02-24          108295.0  108275.0  ...    4.994828           14.675031
#
# ...

# %%
print(df2['AfAm_Dist'].mean())
print(df2['White_Dist'].mean())
print(df2['Hispanic_Dist'].mean())
print(df2['Asian_Dist'].mean())
print(df2['Other_Dist'].mean())
print(df2['Not_Available_Dist'].mean())
# Out:
# 30.50927024772331
# 25.81714659934562
# 21.0504151802727
# 1.9827999791988047
# 4.61181304456332
# 16.02855494889622

# %%
ax=df2[['AfAm_Dist', 'White_Dist', 'Hispanic_Dist', 'Asian_Dist']].plot(figsize=(24,10), lw=6, title='Change in Complete Real Gross Domestic Product Over Time');
ax.set_xlabel("Date")
ax.set_ylabel("Distribution Cases in Maryland")
# Out:
# Text(0, 0.5, 'Distribution Cases in Maryland')

# %%
df3 = pd.read_excel('/content/MD_COVID19_TotalVaccinationsStatewideFirstandSecondDose.xlsx')

# %%
df3.head()
# Out:
#   MD_COVID19_TotalVaccinationsStatewideFirstandSecondDose  ...                    Unnamed: 10
# 0                                           OBJECTID       ...  American_Indian_Alaska_Native
# 1                                                  1       ...                              0
# 2                                                  1       ...                              0
# 3                                                  1       ...                              1
# 4                                                  1       ...                              5
#
# [5 rows x 11 columns]

# %%
df3 = pd.read_excel('/content/MD_COVID19_TotalVaccinationsStatewideFirstandSecondDose.xlsx', skiprows=[0])

# %%
df3.head()
# Out:
#    OBJECTID  ... American_Indian_Alaska_Native
# 0         1  ...                             0
# 1         1  ...                             0
# 2         1  ...                             1
# 3         1  ...                             5
# 4         1  ...                            18
#
# [5 rows x 11 columns]

# %%
df3.dtypes
# Out:
# OBJECTID                                   int64
# DATE                                      object
# CumulativeTotalVaccinatedDoseOn            int64
# CumulativeTotalVaccinatedDoseTw            int64
# CumulativeTotalVaccinated                  int64
# White_Vacc                                 int64
# Black_Or_African_American                  int64
# Asian_Vacc                                 int64
# Other_Race                                 int64
# Native_Hawaiian_Other_Pacific_Islander     int64
# American_Indian_Alaska_Native              int64
# dtype: object

# %%
df3=df3.drop(['OBJECTID'], axis=1)

# %%
df3.head()
# Out:
#           DATE  ...  American_Indian_Alaska_Native
# 0  2020/12/14   ...                              0
# 1   2020/12/15  ...                              0
# 2   2020/12/16  ...                              1
# 3   2020/12/17  ...                              5
# 4   2020/12/18  ...                             18
#
# [5 rows x 10 columns]

# %%
df3['DATE'] = pd.to_datetime(df3['DATE'])

# %%
df3=df3.set_index('DATE')

# %%
df3.index
# Out:
# DatetimeIndex(['2020-12-14', '2020-12-15', '2020-12-16', '2020-12-17',
#                '2020-12-18', '2020-12-19', '2020-12-20', '2020-12-21',
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31', '2021-01-01', '2021-01-02',
#                '2021-01-03', '2021-01-04', '2021-01-05', '2021-01-06',
#                '2021-01-07', '2021-01-08', '2021-01-09', '2021-01-10',
#                '2021-01-11', '2021-01-12', '2021-01-13', '2021-01-14',
#                '2021-01-15', '2021-01-16', '2021-01-17', '2021-01-18',
#                '2021-01-19', '2021-01-20', '2021-01-21', '2021-01-22',
#                '2021-01-23', '2021-01-24', '2021-01-25', '2021-01-26',
#                '2021-01-27', '2021-01-28', '2021-01-29', '2021-01-30',
#                '2021-01-31', '2021-02-01', '2021-02-02', '2021-02-03',
# ...

# %%
df3.head()
# Out:
#             CumulativeTotalVaccinatedDoseOn  ...  American_Indian_Alaska_Native
# DATE                                         ...
# 2020-12-14                                2  ...                              0
# 2020-12-15                                9  ...                              0
# 2020-12-16                              545  ...                              1
# 2020-12-17                             1583  ...                              5
# 2020-12-18                             4423  ...                             18
#
# [5 rows x 9 columns]

# %%
df_row = pd.concat([df3, df2])

# %%
df_row
# Out:
#             CumulativeTotalVaccinatedDoseOn  ...  Not_Available_Dist
# DATE                                         ...
# 2020-12-14                              2.0  ...                 NaN
# 2020-12-15                              9.0  ...                 NaN
# 2020-12-16                            545.0  ...                 NaN
# 2020-12-17                           1583.0  ...                 NaN
# 2020-12-18                           4423.0  ...                 NaN
# ...                                     ...  ...                 ...
# 2021-02-20                              NaN  ...           13.860493
# 2021-02-21                              NaN  ...           13.847250
# 2021-02-22                              NaN  ...           13.839498
# 2021-02-23                              NaN  ...           13.826477
# 2021-02-24                              NaN  ...           14.675031
#
# [390 rows x 22 columns]

# %%
df_merge_col = pd.merge(df2, df3, on='DATE')

# %%
df_merge_col
# Out:
#             African_American  ...  American_Indian_Alaska_Native
# DATE                          ...
# 2020-12-14           69786.0  ...                              0
# 2020-12-15           70501.0  ...                              0
# 2020-12-16           71159.0  ...                              1
# 2020-12-17           71786.0  ...                              5
# 2020-12-18           72524.0  ...                             18
# ...                      ...  ...                            ...
# 2021-02-20          107295.0  ...                             26
# 2021-02-21          107496.0  ...                             25
# 2021-02-22          107690.0  ...                             11
# 2021-02-23          107945.0  ...                             24
# 2021-02-24          108295.0  ...                             45
#
# [73 rows x 22 columns]

# %%
df_outer = pd.merge(df2, df3, on='DATE', how='outer')

# %%
df_outer
# Out:
#             African_American  ...  American_Indian_Alaska_Native
# DATE                          ...
# 2020-04-13            3512.0  ...                            NaN
# 2020-04-15            3724.0  ...                            NaN
# 2020-04-16            3978.0  ...                            NaN
# 2020-04-17            4301.0  ...                            NaN
# 2020-04-18            4557.0  ...                            NaN
# ...                      ...  ...                            ...
# 2021-02-20          107295.0  ...                           26.0
# 2021-02-21          107496.0  ...                           25.0
# 2021-02-22          107690.0  ...                           11.0
# 2021-02-23          107945.0  ...                           24.0
# 2021-02-24          108295.0  ...                           45.0
#
# [317 rows x 22 columns]

# %%
df_outer.loc['2020-12-14']
# Out:
# African_American                           69786.000000
# White                                      74295.000000
# Hispanic                                   42968.000000
# Asian                                       4790.000000
# Other                                      10853.000000
# Not_Available                              34269.000000
# Total_Cases                               236961.000000
# AfAm_Dist                                     29.450416
# White_Dist                                    31.353261
# Hispanic_Dist                                 18.132942
# Asian_Dist                                     2.021430
# Other_Dist                                     4.580079
# Not_Available_Dist                            14.461873
# CumulativeTotalVaccinatedDoseOn                2.000000
# CumulativeTotalVaccinatedDoseTw                0.000000
# CumulativeTotalVaccinated                      2.000000
# White_Vacc                                     2.000000
# ...

# %%
df_outer['TotalWhite_Vacc'] = df_outer.White_Vacc.cumsum()

# %%
df_outer.loc['2020-12-14']
# Out:
# African_American                           69786.000000
# White                                      74295.000000
# Hispanic                                   42968.000000
# Asian                                       4790.000000
# Other                                      10853.000000
# Not_Available                              34269.000000
# Total_Cases                               236961.000000
# AfAm_Dist                                     29.450416
# White_Dist                                    31.353261
# Hispanic_Dist                                 18.132942
# Asian_Dist                                     2.021430
# Other_Dist                                     4.580079
# Not_Available_Dist                            14.461873
# CumulativeTotalVaccinatedDoseOn                2.000000
# CumulativeTotalVaccinatedDoseTw                0.000000
# CumulativeTotalVaccinated                      2.000000
# White_Vacc                                     2.000000
# ...

# %%
df_outer.loc['2020-12-28']
# Out:
# African_American                           78325.000000
# White                                      86664.000000
# Hispanic                                   47107.000000
# Asian                                       5588.000000
# Other                                      12364.000000
# Not_Available                              39135.000000
# Total_Cases                               269183.000000
# AfAm_Dist                                     29.097306
# White_Dist                                    32.195198
# Hispanic_Dist                                 17.499991
# Asian_Dist                                     2.075911
# Other_Dist                                     4.593158
# Not_Available_Dist                            14.538437
# CumulativeTotalVaccinatedDoseOn            36376.000000
# CumulativeTotalVaccinatedDoseTw               14.000000
# CumulativeTotalVaccinated                  36390.000000
# White_Vacc                                  5172.000000
# ...

# %%
df_outer['TotalBlackOrAfricanAmerican_Vacc'] = df_outer.Black_Or_African_American.cumsum()

# %%
df_outer.loc['2020-12-28']
# Out:
# African_American                           78325.000000
# White                                      86664.000000
# Hispanic                                   47107.000000
# Asian                                       5588.000000
# Other                                      12364.000000
# Not_Available                              39135.000000
# Total_Cases                               269183.000000
# AfAm_Dist                                     29.097306
# White_Dist                                    32.195198
# Hispanic_Dist                                 17.499991
# Asian_Dist                                     2.075911
# Other_Dist                                     4.593158
# Not_Available_Dist                            14.538437
# CumulativeTotalVaccinatedDoseOn            36376.000000
# CumulativeTotalVaccinatedDoseTw               14.000000
# CumulativeTotalVaccinated                  36390.000000
# White_Vacc                                  5172.000000
# ...

# %%
df_outer['TotalAsian_Vacc'] = df_outer.Asian_Vacc.cumsum()
df_outer['TotalOther_Race_Vacc'] = df_outer.Other_Race.cumsum()
df_outer['TotalNative_Hawaiian_Other_Pacific_Islander_Vacc'] = df_outer.Native_Hawaiian_Other_Pacific_Islander.cumsum()
df_outer['TotalAmerican_Indian_Alaska_Native_Vacc'] = df_outer.American_Indian_Alaska_Native.cumsum()

# %%
df_outer.loc['2020-12-28']
# Out:
# African_American                                     78325.000000
# White                                                86664.000000
# Hispanic                                             47107.000000
# Asian                                                 5588.000000
# Other                                                12364.000000
# Not_Available                                        39135.000000
# Total_Cases                                         269183.000000
# AfAm_Dist                                               29.097306
# White_Dist                                              32.195198
# Hispanic_Dist                                           17.499991
# Asian_Dist                                               2.075911
# Other_Dist                                               4.593158
# Not_Available_Dist                                      14.538437
# CumulativeTotalVaccinatedDoseOn                      36376.000000
# ...

# %%
df_outer.loc['2020-12-28', 'TotalWhite_Vacc'] + df_outer.loc['2020-12-28', 'TotalBlackOrAfricanAmerican_Vacc'] + df_outer.loc['2020-12-28', 'TotalAsian_Vacc'] + df_outer.loc['2020-12-28', 'TotalOther_Race_Vacc'] + df_outer.loc['2020-12-28', 'TotalNative_Hawaiian_Other_Pacific_Islander_Vacc'] + df_outer.loc['2020-12-28', 'TotalAmerican_Indian_Alaska_Native_Vacc']
# Out:
# 36390.0

# %%
ax=df_outer[['Total_Cases','CumulativeTotalVaccinated']].plot(figsize=(24,10), lw=6, title='Change in Complete Real Gross Domestic Product Over Time');
ax.set_xlabel("Date")
ax.set_ylabel("Cases in Maryland")
# Out:
# Text(0, 0.5, 'Cases in Maryland')

# %%
df5=df_outer

# %%
df5.head()
# Out:
#             African_American  ...  TotalAmerican_Indian_Alaska_Native_Vacc
# DATE                          ...
# 2020-04-13            3512.0  ...                                      NaN
# 2020-04-15            3724.0  ...                                      NaN
# 2020-04-16            3978.0  ...                                      NaN
# 2020-04-17            4301.0  ...                                      NaN
# 2020-04-18            4557.0  ...                                      NaN
#
# [5 rows x 28 columns]

# %%
df5
# Out:
#             African_American  ...  TotalAmerican_Indian_Alaska_Native_Vacc
# DATE                          ...
# 2020-04-13            3512.0  ...                                      NaN
# 2020-04-15            3724.0  ...                                      NaN
# 2020-04-16            3978.0  ...                                      NaN
# 2020-04-17            4301.0  ...                                      NaN
# 2020-04-18            4557.0  ...                                      NaN
# ...                      ...  ...                                      ...
# 2021-02-20          107295.0  ...                                   2253.0
# 2021-02-21          107496.0  ...                                   2278.0
# 2021-02-22          107690.0  ...                                   2289.0
# 2021-02-23          107945.0  ...                                   2313.0
# 2021-02-24          108295.0  ...                                   2358.0
#
# [317 rows x 28 columns]

# %%
WhiteVacc_Dist = []
for index, row in df5.iterrows():
     WhiteVacc_Dist.append((row.TotalWhite_Vacc / row.CumulativeTotalVaccinated * 100))

# %%
df5['WhiteVacc_Dist'] = WhiteVacc_Dist

# %%
AfAmVacc_Dist = []
for index, row in df5.iterrows():
     AfAmVacc_Dist.append((row.TotalBlackOrAfricanAmerican_Vacc / row.CumulativeTotalVaccinated * 100))

AsianVacc_Dist = []
for index, row in df5.iterrows():
     AsianVacc_Dist.append((row.TotalAsian_Vacc / row.CumulativeTotalVaccinated * 100))    

OtherVacc_Dist = []
for index, row in df5.iterrows():
     OtherVacc_Dist.append((row.TotalOther_Race_Vacc / row.CumulativeTotalVaccinated * 100))

Native_Hawaiian_Other_Pacific_Islander_Vacc_Dist = []
for index, row in df5.iterrows():
     Native_Hawaiian_Other_Pacific_Islander_Vacc_Dist.append((row.TotalNative_Hawaiian_Other_Pacific_Islander_Vacc  / row.CumulativeTotalVaccinated * 100)) 

American_Indian_Alaska_Native_Vacc_Dist = []
for index, row in df5.iterrows():
     American_Indian_Alaska_Native_Vacc_Dist.append((row.TotalAmerican_Indian_Alaska_Native_Vacc / row.CumulativeTotalVaccinated * 100))

# %%
df5['AfAmVacc_Dist'] = AfAmVacc_Dist

df5['AsianVacc_Dist'] = AsianVacc_Dist

df5['OtherVacc_Dist'] = OtherVacc_Dist

df5['Native_Hawaiian_Other_Pacific_Islander_Vacc_Dist'] = Native_Hawaiian_Other_Pacific_Islander_Vacc_Dist

df5['American_Indian_Alaska_Native_Vacc_Dist'] = American_Indian_Alaska_Native_Vacc_Dist

# %%
df5.loc['2020-12-28']
# Out:
# African_American                                     78325.000000
# White                                                86664.000000
# Hispanic                                             47107.000000
# Asian                                                 5588.000000
# Other                                                12364.000000
# Not_Available                                        39135.000000
# Total_Cases                                         269183.000000
# AfAm_Dist                                               29.097306
# White_Dist                                              32.195198
# Hispanic_Dist                                           17.499991
# Asian_Dist                                               2.075911
# Other_Dist                                               4.593158
# Not_Available_Dist                                      14.538437
# CumulativeTotalVaccinatedDoseOn                      36376.000000
# ...

# %%
df5.head()
# Out:
#             African_American  ...  American_Indian_Alaska_Native_Vacc_Dist
# DATE                          ...
# 2020-04-13            3512.0  ...                                      NaN
# 2020-04-15            3724.0  ...                                      NaN
# 2020-04-16            3978.0  ...                                      NaN
# 2020-04-17            4301.0  ...                                      NaN
# 2020-04-18            4557.0  ...                                      NaN
#
# [5 rows x 34 columns]

# %%
ax=df5[['WhiteVacc_Dist', 'AfAmVacc_Dist', 'AsianVacc_Dist', 'OtherVacc_Dist']].plot(figsize=(24,10), lw=6, title='Change in Complete Real Gross Domestic Product Over Time');
ax.set_xlabel("Date")
ax.set_ylabel("Distribution Cases in Maryland")
# Out:
# Text(0, 0.5, 'Distribution Cases in Maryland')

# %%
df5.loc['2021-02-23']
# Out:
# African_American                                    1.079450e+05
# White                                               1.303440e+05
# Hispanic                                            6.065100e+04
# Asian                                               8.479000e+03
# Other                                               1.774300e+04
# Not_Available                                       5.217200e+04
# Total_Cases                                         3.773340e+05
# AfAm_Dist                                           2.860728e+01
# White_Dist                                          3.454340e+01
# Hispanic_Dist                                       1.607356e+01
# Asian_Dist                                          2.247081e+00
# Other_Dist                                          4.702200e+00
# Not_Available_Dist                                  1.382648e+01
# CumulativeTotalVaccinatedDoseOn                     7.469190e+05
# ...

# %%
df5
# Out:
#             African_American  ...  American_Indian_Alaska_Native_Vacc_Dist
# DATE                          ...
# 2020-04-13            3512.0  ...                                      NaN
# 2020-04-15            3724.0  ...                                      NaN
# 2020-04-16            3978.0  ...                                      NaN
# 2020-04-17            4301.0  ...                                      NaN
# 2020-04-18            4557.0  ...                                      NaN
# ...                      ...  ...                                      ...
# 2021-02-20          107295.0  ...                                 0.215683
# 2021-02-21          107496.0  ...                                 0.213427
# 2021-02-22          107690.0  ...                                 0.210563
# 2021-02-23          107945.0  ...                                 0.207882
# 2021-02-24          108295.0  ...                                 0.205174
#
# [317 rows x 34 columns]

# %%
df6 = pd.read_excel('/content/SeriesReport-20210228180835_bbfb44.xlsx')

# %%
df6.head()
# Out:
#       Year Period  ...  Asian  HispanicOrLatino
# 0  2020-01    Jan  ...    3.1               4.3
# 1  2020-02    Feb  ...    2.4               4.4
# 2  2020-03    Mar  ...    4.1               6.0
# 3  2020-04    Apr  ...   14.5              18.9
# 4  2020-05    May  ...   14.9              17.6
#
# [5 rows x 12 columns]

# %%
df6=df6.drop(['Period'], axis=1)

# %%
df6['Year'] = pd.to_datetime(df6['Year'])

# %%
df6=df6.set_index('Year')

# %%
df6.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#                '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#                '2021-01-01', '2021-02-01', '2021-03-01'],
#               dtype='datetime64[ns]', name='Year', freq=None)

# %%
df6
# Out:
#             laborforceparticipationrate  ...  HispanicOrLatino
# Year                                     ...
# 2020-01-01                         68.7  ...               4.3
# 2020-02-01                         68.8  ...               4.4
# 2020-03-01                         68.9  ...               6.0
# 2020-04-01                         65.2  ...              18.9
# 2020-05-01                         65.3  ...              17.6
# 2020-06-01                         67.4  ...              14.5
# 2020-07-01                         67.9  ...              12.7
# 2020-08-01                         67.9  ...              10.5
# 2020-09-01                         64.6  ...              10.3
# 2020-10-01                         65.9  ...               8.8
# 2020-11-01                         65.6  ...               8.4
# 2020-12-01                         65.6  ...               9.3
# 2021-01-01                         65.6  ...               9.2
# ...

# %%
print(df6.head(20))
# Out:
#             laborforceparticipationrate  ...  HispanicOrLatino
# Year                                     ...
# 2020-01-01                         68.7  ...               4.3
# 2020-02-01                         68.8  ...               4.4
# 2020-03-01                         68.9  ...               6.0
# 2020-04-01                         65.2  ...              18.9
# 2020-05-01                         65.3  ...              17.6
# 2020-06-01                         67.4  ...              14.5
# 2020-07-01                         67.9  ...              12.7
# 2020-08-01                         67.9  ...              10.5
# 2020-09-01                         64.6  ...              10.3
# 2020-10-01                         65.9  ...               8.8
# 2020-11-01                         65.6  ...               8.4
# 2020-12-01                         65.6  ...               9.3
# 2021-01-01                         65.6  ...               9.2
# ...

# %%
Daily = df6.resample('D')

# %%
DailyEstimate = Daily.interpolate(method='linear')

# %%
print(DailyEstimate.head(20))
# Out:
#             laborforceparticipationrate  ...  HispanicOrLatino
# Year                                     ...
# 2020-01-01                    68.700000  ...          4.300000
# 2020-01-02                    68.703226  ...          4.303226
# 2020-01-03                    68.706452  ...          4.306452
# 2020-01-04                    68.709677  ...          4.309677
# 2020-01-05                    68.712903  ...          4.312903
# 2020-01-06                    68.716129  ...          4.316129
# 2020-01-07                    68.719355  ...          4.319355
# 2020-01-08                    68.722581  ...          4.322581
# 2020-01-09                    68.725806  ...          4.325806
# 2020-01-10                    68.729032  ...          4.329032
# 2020-01-11                    68.732258  ...          4.332258
# 2020-01-12                    68.735484  ...          4.335484
# 2020-01-13                    68.738710  ...          4.338710
# ...

# %%
DailyEstimate.head()
# Out:
#             laborforceparticipationrate  ...  HispanicOrLatino
# Year                                     ...
# 2020-01-01                    68.700000  ...          4.300000
# 2020-01-02                    68.703226  ...          4.303226
# 2020-01-03                    68.706452  ...          4.306452
# 2020-01-04                    68.709677  ...          4.309677
# 2020-01-05                    68.712903  ...          4.312903
#
# [5 rows x 10 columns]
