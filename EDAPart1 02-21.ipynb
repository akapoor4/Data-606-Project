# %%
import pandas as pd

# %%
df = pd.read_excel('/content/MDCOVID19_CasesByRaceAndEthnicityDistribution.xlsx')

# %%
df
# Out:
#     MDCOVID19_CasesByRaceAndEthnicityDistribution (2)  ...     Unnamed: 7
# 0                                            OBJECTID  ...  Not_Available
# 1                                                   1  ...            922
# 2                                                   2  ...            NaN
# 3                                                   3  ...           1354
# 4                                                   4  ...           1507
# ..                                                ...  ...            ...
# 316                                               316  ...          51861
# 317                                               317  ...          51871
# 318                                               318  ...          51894
# 319                                               319  ...          51981
# 320                                               320  ...          52035
#
# [321 rows x 8 columns]

# %%
df = pd.read_excel('/content/MDCOVID19_CasesByRaceAndEthnicityDistribution.xlsx', skiprows=[0])

# %%
df
# Out:
#      OBJECTID         DATE  African_American  ...   Asian    Other  Not_Available
# 0           1  2020/04/06             1521.0  ...    74.0    321.0          922.0
# 1           2   2020/04/07               NaN  ...     NaN      NaN            NaN
# 2           3   2020/04/08            2064.0  ...   122.0    449.0         1354.0
# 3           4   2020/04/09            2304.0  ...   136.0    544.0         1507.0
# 4           5   2020/04/10            2599.0  ...   153.0    643.0         1690.0
# ..        ...          ...               ...  ...     ...      ...            ...
# 315       316   2021/02/15          105906.0  ...  8298.0  17415.0        51861.0
# 316       317   2021/02/16          106062.0  ...  8316.0  17447.0        51871.0
# 317       318   2021/02/17          106360.0  ...  8340.0  17497.0        51894.0
# 318       319   2021/02/18          106711.0  ...  8370.0  17535.0        51981.0
# 319       320   2021/02/19          107034.0  ...  8403.0  17594.0        52035.0
#
# [320 rows x 8 columns]

# %%
df.head()
# Out:
#    OBJECTID         DATE  African_American  ...  Asian  Other  Not_Available
# 0         1  2020/04/06             1521.0  ...   74.0  321.0          922.0
# 1         2   2020/04/07               NaN  ...    NaN    NaN            NaN
# 2         3   2020/04/08            2064.0  ...  122.0  449.0         1354.0
# 3         4   2020/04/09            2304.0  ...  136.0  544.0         1507.0
# 4         5   2020/04/10            2599.0  ...  153.0  643.0         1690.0
#
# [5 rows x 8 columns]

# %%
df.dtypes
# Out:
# OBJECTID              int64
# DATE                 object
# African_American    float64
# White               float64
# Hispanic            float64
# Asian               float64
# Other               float64
# Not_Available       float64
# dtype: object

# %%
df.drop(['OBJECTID'], axis=1)
# Out:
#             DATE  African_American     White  ...   Asian    Other  Not_Available
# 0    2020/04/06             1521.0    1207.0  ...    74.0    321.0          922.0
# 1     2020/04/07               NaN       NaN  ...     NaN      NaN            NaN
# 2     2020/04/08            2064.0    1540.0  ...   122.0    449.0         1354.0
# 3     2020/04/09            2304.0    1694.0  ...   136.0    544.0         1507.0
# 4     2020/04/10            2599.0    1883.0  ...   153.0    643.0         1690.0
# ..           ...               ...       ...  ...     ...      ...            ...
# 315   2021/02/15          105906.0  127950.0  ...  8298.0  17415.0        51861.0
# 316   2021/02/16          106062.0  128167.0  ...  8316.0  17447.0        51871.0
# 317   2021/02/17          106360.0  128441.0  ...  8340.0  17497.0        51894.0
# 318   2021/02/18          106711.0  128821.0  ...  8370.0  17535.0        51981.0
# 319   2021/02/19          107034.0  129257.0  ...  8403.0  17594.0        52035.0
#
# [320 rows x 7 columns]

# %%
Total_Cases = []
for index, row in df.iterrows():
     Total_Cases.append(row.African_American + row.White + row.Hispanic + row.Asian + row.Other + row.Not_Available)

# %%
Total_Cases
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  8936.0,
#  nan,
#  10032.0,
#  10784.0,
#  11572.0,
#  12308.0,
#  12830.0,
#  13684.0,
#  14193.0,
#  14775.0,
#  15737.0,
#  16616.0,
#  17766.0,
#  18581.0,
#  19487.0,
#  20113.0,
#  20849.0,
#  21742.0,
#  23472.0,
#  24473.0,
#  25462.0,
#  26408.0,
#  27117.0,
#  28163.0,
#  29374.0,
#  30485.0,
#  31534.0,
#  32587.0,
#  33373.0,
#  34061.0,
#  34812.0,
#  35903.0,
#  36986.0,
#  37968.0,
#  38804.0,
#  39762.0,
#  41546.0,
#  42323.0,
#  43531.0,
#  44424.0,
#  45495.0,
#  46313.0,
#  47152.0,
#  47687.0,
#  48423.0,
#  49709.0,
#  50988.0,
#  52015.0,
#  52778.0,
#  53327.0,
#  54175.0,
#  54982.0,
#  55858.0,
#  56770.0,
#  57482.0,
#  57973.0,
#  58404.0,
#  58904.0,
#  59465.0,
#  60197.0,
#  60613.0,
#  61305.0,
#  61701.0,
#  62032.0,
#  62409.0,
#  62969.0,
#  63229.0,
#  63548.0,
#  63956.0,
#  64306.0,
#  64603.0,
#  65007.0,
#  65337.0,
#  65777.0,
#  66115.0,
#  66450.0,
#  66777.0,
#  67254.0,
#  67559.0,
#  67918.0,
#  67918.0,
#  68961.0,
#  69341.0,
#  69632.0,
#  69904.0,
#  70396.0,
#  70861.0,
#  71447.0,
#  71910.0,
#  72467.0,
#  73109.0,
#  73527.0,
#  74260.0,
#  75016.0,
#  75664.0,
#  76371.0,
#  77206.0,
#  78131.0,
#  78685.0,
#  79545.0,
#  79730.0,
#  80836.0,
#  81766.0,
#  83054.0,
#  83748.0,
#  84876.0,
#  85524.0,
#  86285.0,
#  87177.0,
#  88346.0,
#  89365.0,
#  90274.0,
#  91144.0,
#  91854.0,
#  92426.0,
#  93005.0,
#  93806.0,
#  94581.0,
#  95503.0,
#  96258.0,
#  96843.0,
#  97384.0,
#  98160.0,
#  98875.0,
#  99693.0,
#  100212.0,
#  100715.0,
#  101235.0,
#  101649.0,
#  102229.0,
#  102899.0,
#  103523.0,
#  104102.0,
#  104669.0,
#  105046.0,
#  105486.0,
#  106063.0,
#  106664.0,
#  107294.0,
#  107791.0,
#  108249.0,
#  108863.0,
#  109319.0,
#  110012.0,
#  110831.0,
#  111607.0,
#  112119.0,
#  112883.0,
#  113239.0,
#  113575.0,
#  114078.0,
#  114724.0,
#  115533.0,
#  116110.0,
#  116646.0,
#  117245.0,
#  117888.0,
#  118519.0,
#  119062.0,
#  119744.0,
#  120156.0,
#  120568.0,
#  120912.0,
#  121297.0,
#  121800.0,
#  122359.0,
#  122972.0,
#  123403.0,
#  123880.0,
#  124311.0,
#  124725.0,
#  125510.0,
#  126221.0,
#  126819.0,
#  127290.0,
#  127791.0,
#  128204.0,
#  128664.0,
#  129425.0,
#  130159.0,
#  130795.0,
#  131357.0,
#  131861.0,
#  132343.0,
#  132918.0,
#  133548.0,
#  134329.0,
#  135127.0,
#  135657.0,
#  136154.0,
#  136744.0,
#  137236.0,
#  137979.0,
#  138691.0,
#  139487.0,
#  140279.0,
#  140844.0,
#  141741.0,
#  142425.0,
#  143387.0,
#  144314.0,
#  145281.0,
#  146145.0,
#  146995.0,
#  147766.0,
#  148766.0,
#  149964.0,
#  151505.0,
#  152915.0,
#  153996.0,
#  155371.0,
#  156709.0,
#  158423.0,
#  159900.0,
#  161769.0,
#  164090.0,
#  165930.0,
#  167656.0,
#  169805.0,
#  171823.0,
#  174733.0,
#  177086.0,
#  179971.0,
#  182139.0,
#  183797.0,
#  185464.0,
#  188161.0,
#  190480.0,
#  192858.0,
#  194448.0,
#  196447.0,
#  198370.0,
#  201135.0,
#  203355.0,
#  205399.0,
#  209191.0,
#  212384.0,
#  215027.0,
#  217329.0,
#  219961.0,
#  222653.0,
#  225855.0,
#  228471.0,
#  232009.0,
#  234647.0,
#  236961.0,
#  239362.0,
#  241767.0,
#  243984.0,
#  246553.0,
#  248754.0,
#  250808.0,
#  253073.0,
#  255397.0,
#  257862.0,
#  260728.0,
#  263160.0,
#  265440.0,
#  267198.0,
#  269183.0,
#  271061.0,
#  273689.0,
#  276662.0,
#  280219.0,
#  283171.0,
#  285319.0,
#  287802.0,
#  289758.0,
#  292904.0,
#  295874.0,
#  299606.0,
#  303364.0,
#  306674.0,
#  309686.0,
#  312351.0,
#  314867.0,
#  317815.0,
#  320739.0,
#  324031.0,
#  326445.0,
#  328214.0,
#  330186.0,
#  332353.0,
#  334519.0,
#  336915.0,
#  339307.0,
#  341452.0,
#  343138.0,
#  344620.0,
#  346559.0,
#  348749.0,
#  350629.0,
#  352726.0,
#  354473.0,
#  355636.0,
#  356541.0,
#  357483.0,
#  359037.0,
#  360584.0,
#  362084.0,
#  363650.0,
#  364553.0,
#  365529.0,
#  366666.0,
#  367865.0,
#  368977.0,
#  370136.0,
#  370983.0,
#  371705.0,
#  372221.0,
#  372980.0,
#  373966.0,
#  374974.0]

# %%
df['Total_Cases'] = Total_Cases

# %%
df.head()
# Out:
#    OBJECTID         DATE  African_American  ...  Other  Not_Available  Total_Cases
# 0         1  2020/04/06             1521.0  ...  321.0          922.0          NaN
# 1         2   2020/04/07               NaN  ...    NaN            NaN          NaN
# 2         3   2020/04/08            2064.0  ...  449.0         1354.0          NaN
# 3         4   2020/04/09            2304.0  ...  544.0         1507.0          NaN
# 4         5   2020/04/10            2599.0  ...  643.0         1690.0          NaN
#
# [5 rows x 9 columns]

# %%
df.dropna(how='all')
# Out:
#      OBJECTID         DATE  ...  Not_Available  Total_Cases
# 0           1  2020/04/06   ...          922.0          NaN
# 1           2   2020/04/07  ...            NaN          NaN
# 2           3   2020/04/08  ...         1354.0          NaN
# 3           4   2020/04/09  ...         1507.0          NaN
# 4           5   2020/04/10  ...         1690.0          NaN
# ..        ...          ...  ...            ...          ...
# 315       316   2021/02/15  ...        51861.0     371705.0
# 316       317   2021/02/16  ...        51871.0     372221.0
# 317       318   2021/02/17  ...        51894.0     372980.0
# 318       319   2021/02/18  ...        51981.0     373966.0
# 319       320   2021/02/19  ...        52035.0     374974.0
#
# [320 rows x 9 columns]

# %%
df1=df.dropna()

# %%
df1
# Out:
#      OBJECTID        DATE  ...  Not_Available  Total_Cases
# 7           8  2020/04/13  ...         1705.0       8936.0
# 9          10  2020/04/15  ...         2221.0      10032.0
# 10         11  2020/04/16  ...         2476.0      10784.0
# 11         12  2020/04/17  ...         2552.0      11572.0
# 12         13  2020/04/18  ...         2669.0      12308.0
# ..        ...         ...  ...            ...          ...
# 315       316  2021/02/15  ...        51861.0     371705.0
# 316       317  2021/02/16  ...        51871.0     372221.0
# 317       318  2021/02/17  ...        51894.0     372980.0
# 318       319  2021/02/18  ...        51981.0     373966.0
# 319       320  2021/02/19  ...        52035.0     374974.0
#
# [312 rows x 9 columns]

# %%
df1.count()
# Out:
# OBJECTID            312
# DATE                312
# African_American    312
# White               312
# Hispanic            312
# Asian               312
# Other               312
# Not_Available       312
# Total_Cases         312
# dtype: int64

# %%
df1.head()
# Out:
#     OBJECTID        DATE  African_American  ...  Other  Not_Available  Total_Cases
# 7          8  2020/04/13            3512.0  ...  961.0         1705.0       8936.0
# 9         10  2020/04/15            3724.0  ...  357.0         2221.0      10032.0
# 10        11  2020/04/16            3978.0  ...  376.0         2476.0      10784.0
# 11        12  2020/04/17            4301.0  ...  429.0         2552.0      11572.0
# 12        13  2020/04/18            4557.0  ...  458.0         2669.0      12308.0
#
# [5 rows x 9 columns]

# %%
df1.dtypes
# Out:
# OBJECTID              int64
# DATE                 object
# African_American    float64
# White               float64
# Hispanic            float64
# Asian               float64
# Other               float64
# Not_Available       float64
# Total_Cases         float64
# dtype: object

# %%
df1['DATE'] = pd.to_datetime(df1['DATE'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1=df1.set_index('DATE')

# %%
df1.index
# Out:
# DatetimeIndex(['2020-04-13', '2020-04-15', '2020-04-16', '2020-04-17',
#                '2020-04-18', '2020-04-19', '2020-04-20', '2020-04-21',
#                '2020-04-22', '2020-04-23',
#                ...
#                '2021-02-10', '2021-02-11', '2021-02-12', '2021-02-13',
#                '2021-02-14', '2021-02-15', '2021-02-16', '2021-02-17',
#                '2021-02-18', '2021-02-19'],
#               dtype='datetime64[ns]', name='DATE', length=312, freq=None)

# %%
df1
# Out:
#             OBJECTID  African_American  ...  Not_Available  Total_Cases
# DATE                                    ...
# 2020-04-13         8            3512.0  ...         1705.0       8936.0
# 2020-04-15        10            3724.0  ...         2221.0      10032.0
# 2020-04-16        11            3978.0  ...         2476.0      10784.0
# 2020-04-17        12            4301.0  ...         2552.0      11572.0
# 2020-04-18        13            4557.0  ...         2669.0      12308.0
# ...              ...               ...  ...            ...          ...
# 2021-02-15       316          105906.0  ...        51861.0     371705.0
# 2021-02-16       317          106062.0  ...        51871.0     372221.0
# 2021-02-17       318          106360.0  ...        51894.0     372980.0
# 2021-02-18       319          106711.0  ...        51981.0     373966.0
# 2021-02-19       320          107034.0  ...        52035.0     374974.0
#
# [312 rows x 8 columns]

# %%
df1 = df1.drop(['OBJECTID'], axis=1)

# %%
df1.loc['2021-02-19	']
# Out:
# OBJECTID               320.0
# African_American    107034.0
# White               129257.0
# Hispanic             60651.0
# Asian                 8403.0
# Other                17594.0
# Not_Available        52035.0
# Total_Cases         374974.0
# Name: 2021-02-19 00:00:00, dtype: float64

# %%
ax=df1[['Total_Cases']].plot(figsize=(24,10), lw=6, title='Change in Complete Real Gross Domestic Product Over Time');
ax.set_xlabel("Date")
ax.set_ylabel("Cases in Maryland")

#ax=df1[['Gross Domestic Product','Consumption']].plot(figsize=(24,10),title='Change in Complete Real Gross Domestic Product Over Time');
#ax.set_xlabel("Date")
#ax.set_ylabel("Consumption & GDP")
# Out:
# Text(0, 0.5, 'Cases in Maryland')

# %%
ax=df1[['Total_Cases', 'African_American', 'White', 'Hispanic', 'Asian']].plot(figsize=(24,10), lw=6, title='Change in Complete Real Gross Domestic Product Over Time');
ax.set_xlabel("Date")
ax.set_ylabel("Cases in Maryland")
# Out:
# Text(0, 0.5, 'Cases in Maryland')

# %%
print(df1['Total_Cases'].median())
print(df1['Total_Cases'].mean())
print(df1['Total_Cases'].std())
print(df1['Total_Cases'].var())
print(df1['Total_Cases'].max())
print(df1['Total_Cases'].min())
# Out:
# 118203.5
# 146973.58974358975
# 103202.06700903452
# 10650666634.937252
# 374974.0
# 8936.0

# %%
import seaborn as sns

# %%
sns.pairplot(df1)

# %%
df1.head()
# Out:
#             African_American   White  ...  Not_Available  Total_Cases
# DATE                                  ...
# 2020-04-13            3512.0  2547.0  ...         1705.0       8936.0
# 2020-04-15            3724.0  2425.0  ...         2221.0      10032.0
# 2020-04-16            3978.0  2535.0  ...         2476.0      10784.0
# 2020-04-17            4301.0  2681.0  ...         2552.0      11572.0
# 2020-04-18            4557.0  2869.0  ...         2669.0      12308.0
#
# [5 rows x 7 columns]

# %%
df2=df1

# %%
df2.head()
# Out:
#             OBJECTID  African_American  ...  Not_Available  Total_Cases
# DATE                                    ...
# 2020-04-13         8            3512.0  ...         1705.0       8936.0
# 2020-04-15        10            3724.0  ...         2221.0      10032.0
# 2020-04-16        11            3978.0  ...         2476.0      10784.0
# 2020-04-17        12            4301.0  ...         2552.0      11572.0
# 2020-04-18        13            4557.0  ...         2669.0      12308.0
#
# [5 rows x 8 columns]

# %%
#df1 = df1.drop(['OBJECTID'], axis=1)

# %%
AfAm_Dist = []
for index, row in df2.iterrows():
     AfAm_Dist.append((row.African_American / row.	Total_Cases * 100))

# %%
#df2 = df2.drop(['Percent'], axis=1)

# %%
df2['AfAm_Dist'] = AfAm_Dist

# %%
df2.head()
# Out:
#             African_American   White  ...  Total_Cases  AfAm_Dist
# DATE                                  ...
# 2020-04-13            3512.0  2547.0  ...       8936.0  39.301701
# 2020-04-15            3724.0  2425.0  ...      10032.0  37.121212
# 2020-04-16            3978.0  2535.0  ...      10784.0  36.887982
# 2020-04-17            4301.0  2681.0  ...      11572.0  37.167300
# 2020-04-18            4557.0  2869.0  ...      12308.0  37.024699
#
# [5 rows x 8 columns]

# %%
White_Dist = []
for index, row in df2.iterrows():
     White_Dist.append((row.White / row.Total_Cases * 100))

Hispanic_Dist = []
for index, row in df2.iterrows():
     Hispanic_Dist.append((row.Hispanic / row.Total_Cases * 100))

Asian_Dist = []
for index, row in df2.iterrows():
     Asian_Dist.append((row.Asian / row.Total_Cases * 100))    

Other_Dist = []
for index, row in df2.iterrows():
     Other_Dist.append((row.Other / row.Total_Cases * 100))

Not_Available_Dist = []
for index, row in df2.iterrows():
     Not_Available_Dist.append((row.Not_Available / row.Total_Cases * 100))

# %%
df2['White_Dist'] = White_Dist

df2['Hispanic_Dist'] = Hispanic_Dist

df2['Asian_Dist'] = Asian_Dist

df2['Other_Dist'] = Other_Dist

df2['Not_Available_Dist'] = Not_Available_Dist

# %%
df2.head()
# Out:
#             African_American   White  ...  Other_Dist  Not_Available_Dist
# DATE                                  ...
# 2020-04-13            3512.0  2547.0  ...   10.754252           19.080125
# 2020-04-15            3724.0  2425.0  ...    3.558612           22.139155
# 2020-04-16            3978.0  2535.0  ...    3.486647           22.959941
# 2020-04-17            4301.0  2681.0  ...    3.707224           22.053232
# 2020-04-18            4557.0  2869.0  ...    3.721157           21.685083
#
# [5 rows x 13 columns]

# %%
print(df2['AfAm_Dist'].mean())
print(df2['White_Dist'].mean())
print(df2['Hispanic_Dist'].mean())
print(df2['Asian_Dist'].mean())
print(df2['Other_Dist'].mean())
print(df2['Not_Available_Dist'].mean())
# Out:
# 30.53424153619495
# 25.690794485842215
# 21.12645849443754
# 1.9781366548309256
# 4.609461232811722
# 16.06090759588262

# %%
ax=df2[['AfAm_Dist', 'White_Dist', 'Hispanic_Dist', 'Asian_Dist']].plot(figsize=(24,10), lw=6, title='Change in Complete Real Gross Domestic Product Over Time');
ax.set_xlabel("Date")
ax.set_ylabel("Distribution Cases in Maryland")
# Out:
# Text(0, 0.5, 'Distribution Cases in Maryland')
